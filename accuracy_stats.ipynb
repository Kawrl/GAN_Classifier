# %%
# Rest set:

Accuracy_ReACGAN_rest = [
    99.746,
    99.772,
    99.873,
    99.773,
    99.781,
    99.809
]

Accuracy_ReACGAN_rest_PCA_outliers_normal=[
    99.746,
    99.653,
    99.790,
    99.690

]

Accuracy_ReACGAN_rest_PCA_only_outliers=[
    99.746,
]


# Only real:
real_only = [99.746]
# Out:
# /home/karl/Documents/GeneratedTensors/EvalDataAug/ClassifierNetwork

# %%
from torchsummary import summary
import torch
import torchvision.models as models
import torch.nn as nn


resnet = models.resnet18(pretrained=False)
resnet.fc = nn.Linear(512, 11)

summary(resnet, (3,64,32),1)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1            [1, 64, 32, 16]           9,408
#        BatchNorm2d-2            [1, 64, 32, 16]             128
#               ReLU-3            [1, 64, 32, 16]               0
#          MaxPool2d-4             [1, 64, 16, 8]               0
#             Conv2d-5             [1, 64, 16, 8]          36,864
#        BatchNorm2d-6             [1, 64, 16, 8]             128
#               ReLU-7             [1, 64, 16, 8]               0
#             Conv2d-8             [1, 64, 16, 8]          36,864
#        BatchNorm2d-9             [1, 64, 16, 8]             128
#              ReLU-10             [1, 64, 16, 8]               0
#        BasicBlock-11             [1, 64, 16, 8]               0
#            Conv2d-12             [1, 64, 16, 8]          36,864
#       BatchNorm2d-13             [1, 64, 16, 8]             128
# ...

# %%
# Accuracies with 1/3 outliers:
Accuracy_ReACGAN_200_PCA_outliers_normal=[
    85.565,
    87.256,
    87.744,
    89.197,
    93.862,
    94.216
]

Accuracy_ReACGAN_200_PCA_outliers_normal_FULL=[
    85.565,
    87.288,
    88.244,
    88.979,
    94.134,
    94.505    
]

Accuracy_ReACGAN_200_PCA_only_outliers=[
    85.565,
    86.302,
    87.002,
    86.964,
    86.821,
    88.113
]


Accuracy_ACGAN_200_PCA_outliers_normal_FULL=[
    85.565,
    86.551,
    87.471,
    88.340,
    94.462,
    94.151
]

Accuracy_ACGAN_200_PCA_outliers_normal=[
    85.565,
    86.571,
    87.778,
    87.924,
    93.890,
    94.779
]

Accuracy_ACGAN_200_PCA_only_outliers=[
    85.565,
    86.194,
    86.946,
    87.052,
    86.801,
    91.251
]

Accuracy_ACGAN_200_PCA_only_outliers_FULL=[
    85.565,
    86.631,
    86.895,
    88.270,
    88.214,
    88.323
]

Accuracy_ACGAN_1000_PCA_outliers_normal_FULL=[
    95.063,
    95.124,
    95.699,
    97.027,
    98.043,
    98.862
]

Accuracy_ACGAN_1000_PCA_outliers_normal=[
    95.063,
    95.184,
    95.563,
    97.090,
    97.308,
    98.846
]

Accuracy_ACGAN_1000_PCA_only_outliers=[
    95.063,
    95.148,
    95.625,
    96.273,
    95.663,
    97.417    
]

Accuracy_ACGAN_1000_PCA_only_outliers_FULL=[
    95.063,
    96.261,
    95.663,
    95.864,
    96.609,
    96.791
]

Accuracy_ReACGAN_1000_PCA_outliers_normal=[
    95.063,
    95.100,
    95.381,
    96.655,
    98.436,
    98.755
]

Accuracy_ReACGAN_1000_PCA_outliers_normal_FULL=[
    95.063,
    95.990,
    95.381,
    97.355,
    98.173,
    98.588    
]

Accuracy_ReACGAN_1000_PCA_only_outliers=[
    95.063,
    94.927,
    95.424,
    95.843,
    95.089,
    96.427
]

Accuracy_ReACGAN_1000_PCA_only_outliers_FULL=[
    95.063,
    96.079,
    96.927,
    97.063,
    96.282,
    96.190
]

# %%
# Random sampling:
Accuracy_ReACGAN_200 = [
    85.565,
    86.867,
    87.741,
    88.752,
    94.261,
    95.497
]

Accuracy_ReACGAN_1000 = [
    95.063,
    94.953,
    95.192,
    97.392,
    98.426,
    98.944
]

Accuracy_ACGAN_200=[
    85.565,
    86.266,
    87.017,
    88.484,
    94.608,
    95.616
]

Accuracy_ACGAN_1000 = [
    95.063,
    95.110,
    95.737,
    97.333,
    98.336,
    99.173
]

Accuracy_real=[
    85.565,
    95.063
]

aug_sample_sizes = [
    0,
    100,
    500,
    1000,
    4480,
    8960 # Total size of datasets: 100760 (200 real from each class)
]

# %%
from matplotlib import pyplot as plt

# ACGAN, Random sampling, 200
y0 = Accuracy_ACGAN_200
base_200 = Accuracy_real[0]
base_1000 = Accuracy_real[1]
x = aug_sample_sizes

y1 = Accuracy_ACGAN_200_PCA_outliers_normal_FULL
y2 = Accuracy_ACGAN_200_PCA_outliers_normal
y3 = Accuracy_ACGAN_200_PCA_only_outliers


fig, ax = plt.subplots(figsize=(14,10))
ax.plot(x, y0,label='Random sampling',marker='o')
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')

ax.axhline(base_200,label='Only real data (2 200 images total)',ls='--')
ax.axhline(base_1000,label='Only real data (11 000 images total)',ls='--',c='orange')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=85.0,top=100.0)
ax.set_xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)
plt.savefig('saved_plots/accuracies_ACGAN_random_200.png',bbox_inches='tight')

# %%
y0 = Accuracy_ACGAN_200
base_200 = Accuracy_real[0]
base_1000 = Accuracy_real[1]
x = aug_sample_sizes

y1 = Accuracy_ACGAN_200_PCA_outliers_normal_FULL
y2 = Accuracy_ACGAN_200_PCA_outliers_normal
y3 = Accuracy_ACGAN_200_PCA_only_outliers

fig, (ax, ax2) = plt.subplots(1,2,figsize=(20,10),sharex=True)
ax.set_title('ACGAN')
ax.plot(x, y0,label='Random sampling',marker='o')
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax.axhline(base_200,label='Only real data (2 200 images total)',ls='--')
ax.axhline(base_1000,label='Only real data (11 000 images total)',ls='--',c='orange')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=85.0,top=100.0)
#ax.set_xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)

y0 = Accuracy_ReACGAN_200
x = aug_sample_sizes
y1 = Accuracy_ReACGAN_200_PCA_outliers_normal_FULL
y2 = Accuracy_ReACGAN_200_PCA_outliers_normal
y3 = Accuracy_ReACGAN_200_PCA_only_outliers

#fig, ax = plt.subplots(figsize=(14,10))
ax2.set_title('ReACGAN')
ax2.plot(x, y0,label='Random sampling',marker='o')
ax2.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax2.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax2.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax2.axhline(base_200,label='Only real data (2 200 images total)',ls='--')
ax2.axhline(base_1000,label='Only real data (11 000 images total)',ls='--',c='orange')
ax2.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax2.set_ylim(bottom=85.0,top=100.0)
#ax2.set_xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
ax2.set_ylabel('Accuracy',fontsize=16)
ax2.legend(fontsize=14)
plt.xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
plt.show()

# %%
y0 = Accuracy_ACGAN_1000
x = aug_sample_sizes
y1 = Accuracy_ACGAN_1000_PCA_outliers_normal_FULL
y2 = Accuracy_ACGAN_1000_PCA_outliers_normal
y3 = Accuracy_ACGAN_1000_PCA_only_outliers

fig, (ax, ax2) = plt.subplots(1,2,figsize=(20,10),sharex=True)
ax.set_title('ACGAN')
ax.plot(x, y0,label='ACGAN, Random sampling',marker='o')
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax.axhline(base_1000,label='Only real data',ls='--')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=90.0,top=100.0)
#ax.set_xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)

y0 = Accuracy_ReACGAN_1000
x = aug_sample_sizes
y1 = Accuracy_ReACGAN_1000_PCA_outliers_normal_FULL
y2 = Accuracy_ReACGAN_1000_PCA_outliers_normal
y3 = Accuracy_ReACGAN_1000_PCA_only_outliers

#fig, ax = plt.subplots(figsize=(14,10))
ax2.set_title('ReACGAN')
ax2.plot(x, y0,label='Random sampling',marker='o')
ax2.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax2.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax2.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax2.axhline(base_1000,label='Only real data',ls='--')
ax2.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax2.set_ylim(bottom=90.0,top=100.0)
#ax2.set_xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
ax2.set_ylabel('Accuracy',fontsize=16)
ax2.legend(fontsize=14)
plt.xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
plt.show()

# %%
# ACGAN, Random sampling, 1000
y0 = Accuracy_ACGAN_1000
x = aug_sample_sizes
y1 = Accuracy_ACGAN_1000_PCA_outliers_normal_FULL
y2 = Accuracy_ACGAN_1000_PCA_outliers_normal
y3 = Accuracy_ACGAN_1000_PCA_only_outliers

fig, ax = plt.subplots(figsize=(14,10))
ax.plot(x, y0,label='ACGAN, Random sampling',marker='o')
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax.axhline(base_1000,label='Only real data',ls='--')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=90.0,top=100.0)
ax.set_xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)
plt.savefig('saved_plots/accuracies_ACGAN_random_1000.png',bbox_inches='tight')

# %%
# ReACGAN, Random sampling, 200
y0 = Accuracy_ReACGAN_200
x = aug_sample_sizes
y1 = Accuracy_ReACGAN_200_PCA_outliers_normal_FULL
y2 = Accuracy_ReACGAN_200_PCA_outliers_normal
y3 = Accuracy_ReACGAN_200_PCA_only_outliers


fig, ax = plt.subplots(figsize=(14,10))
ax.plot(x, y0,label='Random sampling',marker='o')
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')

ax.axhline(base_200,label='Only real data (2 200 images total)',ls='--')
ax.axhline(base_1000,label='Only real data (11 000 images total)',ls='--',c='orange')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=85.0,top=100.0)
ax.set_xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)
plt.savefig('saved_plots/accuracies_ReACGAN_random_200.png',bbox_inches='tight')

# %%
# ReACGAN, Random sampling, 1000
y0 = Accuracy_ReACGAN_1000
x = aug_sample_sizes
y1 = Accuracy_ReACGAN_1000_PCA_outliers_normal_FULL
y2 = Accuracy_ReACGAN_1000_PCA_outliers_normal
y3 = Accuracy_ReACGAN_1000_PCA_only_outliers

fig, ax = plt.subplots(figsize=(14,10))
ax.plot(x, y0,label='ReACGAN, Random sampling',marker='o')
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax.axhline(base_1000,label='Only real data',ls='--')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=90.0,top=100.0)
ax.set_xlabel('Number of generated samples added per class (sampled randomly), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)
plt.savefig('saved_plots/accuracies_ReACGAN_random_1000.png',bbox_inches='tight')

# %%
# ACGAN, PCA, 200
y1 = Accuracy_ACGAN_200_PCA_outliers_normal_FULL
y2 = Accuracy_ACGAN_200_PCA_outliers_normal
y3 = Accuracy_ACGAN_200_PCA_only_outliers
x = aug_sample_sizes

fig, ax = plt.subplots(figsize=(14,10))
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax.axhline(base_200,label='Only real data (2 200 images total)',ls='--')
ax.axhline(base_1000,label='Only real data (11 000 images total)',ls='--',c='orange')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=85.0,top=100.0)
ax.set_xlabel('Number of generated samples added per class (sampled using PCA subspace), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)
plt.savefig('saved_plots/accuracies_ACGAN_PCA_200.png',bbox_inches='tight')

# %%
# ACGAN, PCA, 1000
y1 = Accuracy_ACGAN_1000_PCA_outliers_normal_FULL
y2 = Accuracy_ACGAN_1000_PCA_outliers_normal
y3 = Accuracy_ACGAN_1000_PCA_only_outliers
x = aug_sample_sizes[:5]

fig, ax = plt.subplots(figsize=(14,10))
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax.axhline(base_1000,label='Only real data',ls='--')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=90.0,top=100.0)
ax.set_xlabel('Number of generated samples added per class (sampled using PCA subspace), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)
plt.savefig('saved_plots/accuracies_ACGAN_PCA_1000.png',bbox_inches='tight')

# %%
# ReACGAN, PCA, 200
y1 = Accuracy_ReACGAN_200_PCA_outliers_normal_FULL
y2 = Accuracy_ReACGAN_200_PCA_outliers_normal
y3 = Accuracy_ReACGAN_200_PCA_only_outliers
x = aug_sample_sizes

fig, ax = plt.subplots(figsize=(14,10))
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax.axhline(base_200,label='Only real data (2 200 images total)',ls='--')
ax.axhline(base_1000,label='Only real data (11 000 images total)',ls='--',c='orange')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=85.0,top=100.0)
ax.set_xlabel('Number of generated samples added per class (sampled using PCA subspace), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)
plt.savefig('saved_plots/accuracies_ReACGAN_PCA_200.png',bbox_inches='tight')

# %%
import numpy as np
val=3
print(aug_sample_sizes[val])
print(np.log10(aug_sample_sizes[val]))
# Out:
# 1000
# 3.0

# %%
# ReACGAN, PCA, 1000
y1 = Accuracy_ReACGAN_1000_PCA_outliers_normal_FULL
y2 = Accuracy_ReACGAN_1000_PCA_outliers_normal
y3 = Accuracy_ReACGAN_1000_PCA_only_outliers
print(len(y1),len(y2),len(y3))
x = aug_sample_sizes

fig, ax = plt.subplots(figsize=(14,10))
ax.plot(x, y1,label='Proportional sampling using subspace from full set',marker='o')
ax.plot(x, y2,label='Proportional sampling using subspace from small set',marker='o')
ax.plot(x, y3,label='Outlier sampling using subspace from small set',marker='o')
ax.axhline(base_1000,label='Only real data',ls='--')
ax.set_xscale('log')
#ax.set_xticks([0,100,500,1000,4480])
#ax.set_xlim(0, 5000)
ax.set_ylim(bottom=90.0,top=100.0)
ax.set_xlabel('Number of generated samples added per class (sampled using PCA subspace), expressed in log10',fontsize=16)
ax.set_ylabel('Accuracy',fontsize=16)
ax.legend(fontsize=14)
plt.savefig('saved_plots/accuracies_ReACGAN_PCA_1000.png',bbox_inches='tight')
# Out:
# 6 6 6

# %%
from pathlib import Path
from cropsdata import create_dataset

acgan200_path = Path('/home/karl/Documents/GeneratedTensors/ACGAN_200/imgs')
acgan1000_path = Path('/home/karl/Documents/GeneratedTensors/ACGAN_1000/imgs')
reacgan200_path = Path('/home/karl/Documents/GeneratedTensors/Baseline_DiffAug_200/imgs')
reacgan1000_path = Path('/home/karl/Documents/GeneratedTensors/Baseline_DiffAug_1000/imgs')

acgan200 = create_dataset(acgan200_path)
acgan1000 = create_dataset(acgan1000_path)
reacgan200 = create_dataset(reacgan200_path)
reacgan1000 = create_dataset(reacgan1000_path)

# %%
# Plot grid with four images from each class:
import numpy as np
import torchvision

def plot_samples(dataset,fname):   
    random_idxs = np.random.randint(low=0,high=len(dataset),size=16)

    imgs = []
    for idx in random_idxs:
        img,label,_ = dataset[idx]
        imgs.append(img)
    grid=torchvision.utils.make_grid(imgs,normalize=False)
    mean=0.5
    std=0.5
    grid = (grid + (mean/std))/(1/std)
    fig, ax = plt.subplots(figsize=(16,16))
    ax.imshow(grid.permute(1, 2, 0))
    ax.set(xticklabels=[], yticklabels=[], xticks=[], yticks=[])
    plt.savefig(fname+'.png',bbox_inches='tight')

# %%
plot_samples(acgan200,'16samples_acgan200')
plot_samples(acgan1000,'16samples_acgan1000')
plot_samples(reacgan200,'16samples_reacgan200')
plot_samples(reacgan1000,'16samples_reacgan1000')
